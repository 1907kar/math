# %%
3**2
# Out:
# 9

# %% [markdown]
# Exponents of same base

# %%
3**2 * 3**4
# Out:
# 729

# %% [markdown]
# Exponents of different base

# %%
3**2 * 4**2
# Out:
# 144

# %%
from IPython.display import display, Math

# %%
display(Math('3^2=%g'%3**2))
# Out:
# $\displaystyle 3^2=9$

# %%
x=5
y=5.1

# %%
ans = x**(3/4)*4**y
display(Math('x^\\frac{3}{4} \\times 4^y=%g'%ans))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 ans = x**(3/4)*4**y
# ----> 2 display(Math('x^\\frac{3}{4} \\times 4^y=%g'%ans))
#
# NameError: name 'Math' is not defined

# %%
ans = 3**3/x**y
display(Math('\\frac{3^3}{x^y}=%g'%ans))
# Out:
# $\displaystyle \frac{3^3}{x^y}=0.00735558$

# %%
ans = 10**(x-4)
display(Math('10^{x-4}=%g'%ans))
# Out:
# $\displaystyle 10^{x-4}=10$
