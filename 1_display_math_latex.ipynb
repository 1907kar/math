# %%
from IPython.display import display, Math

# %%
x = 4
y = 5

# %%
display(Math(f'x + y = {x+y}'))
# Out:
# $\displaystyle x + y = 9$

# %%
display(Math('%g + %g = %g' %(x, y, x+y)))
# Out:
# $\displaystyle 4 + 5 = 9$

# %%
display(Math('\\frac{x}{y}='+f'{x/y}'))
# Out:
# $\displaystyle \frac{x}{y}=0.8$

# %%
display(Math(f'x \\times y={x*y}'))
# Out:
# $\displaystyle x \times y=20$

# %% [markdown]
# Excercise

# %%
x=7
y=-2
z=5

# %%
display(Math('3x(4+y)=42'))
# Out:
# $\displaystyle 3x(4+y)=42$

# %%
ans = 3*x*(4+y)
display(Math(f'3 \\times {x}(4+{y})={ans}'))
# Out:
# $\displaystyle 3 \times 7(4+-2)=42$

# %%
display(Math('-y-\\frac{x+3}{z}=0'))
# Out:
# $\displaystyle -y-\frac{x+3}{z}=0$

# %%
ans = -y-(x+3)/z
display(Math('-%g-\\frac{%g+3}{%g}={%g}' %(y,x,z,ans)))
# Out:
# $\displaystyle --2-\frac{7+3}{5}={0}$
