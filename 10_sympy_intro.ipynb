# %%
import sympy as sp
import numpy as np
from IPython.display import display, Math
sp.init_printing()

# %%
x, y = sp.symbols('x, y')

# %%
x/y
# Out:
# x
# ─
# y

# %%
np.sqrt(2)
# Out:
# np.float64(1.4142135623730951)

# %%
sp.sqrt(2)
# Out:
# √2

# %% [markdown]
# #### Exercises

# %%
x, y = sp.symbols('x, y')

# %%
y * x**2
# Out:
#  2
# x ⋅y

# %%
display(sp.sqrt(4)*x)
# Out:
# 2⋅x

# %%
display(sp.sqrt(x)*sp.sqrt(x))
# Out:
# x

# %% [markdown]
#                             In above exercises all are evaluvated. If we need to print without evaluation use latex coding

# %% [markdown]
# Lets revise some of latex that we saw in first lesson

# %%
display(Math('\\sigma = \\mu \\times \\sqrt{\\frac{1}{n} \\sum_{i=1}^{n} (x_i - \\mu)^2}'))
# Out:
# $\displaystyle \sigma = \mu \times \sqrt{\frac{1}{n} \sum_{i=1}^{n} (x_i - \mu)^2}$

# %% [markdown]
#                 Below one is called subset and superset

# %%
display(Math('x_{mm} + y^{n+2k-15}'))
# Out:
# $\displaystyle x_{mm} + y^{n+2k-15}$

# %%
display(Math('\\frac{1+x}{2v-s^{t+4r}}'))
# Out:
# $\displaystyle \frac{1+x}{2v-s^{t+4r}}$

# %%
display(Math('The answer to the equation is \\frac{1+x}{2v-s^{t+4r}}'))
# Out:
# $\displaystyle The answer to the equation is \frac{1+x}{2v-s^{t+4r}}$

# %%
display(Math('\\text{The answer to the equation is } \\frac{1+x}{2v-s^{t+4r}}'))
# Out:
# $\displaystyle \text{The answer to the equation is } \frac{1+x}{2v-s^{t+4r}}$

# %% [markdown]
#     How to print latex in markdown
#     This cell is not for running code
# The answer to the equation is
# $$\frac{1+x}{2v-s^{t+4r}}$$

# %% [markdown]
# #### Latex Exercises

# %%
display(Math('4x+5y-8z=17'))
# Out:
# $\displaystyle 4x+5y-8z=17$

# %%
display(Math('\\sin(2\\pi f t + \\theta)'))
# Out:
# $\displaystyle \sin(2\pi ft + \theta)$

# %%
display(Math('e=mc^2'))
# Out:
# $\displaystyle e=mc^2$

# %%
display(Math('\\frac{4+5x^2}{(1+x)(1-x)}'))
# Out:
# $\displaystyle \frac{4+5x^2}{(1+x)(1-x)}$
