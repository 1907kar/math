# %%
n = 6
f = 6.0

# %%
for i in range(n):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(f):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 for i in range(f):
#       2     print(i)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
fname = "karthik "
lname = "mk"

print(fname *3)
# Out:
# karthik karthik karthik

# %% [markdown]
# Exercise

# %%
s1 = '4'
s2 = '5.7'
n1 = 6
n2 = 6.8

# convert string to integer
print(int(s1))

# convert string to float
print(float(s2))

# convert to interger to string
print(str(n1))

print(type(str(n1)))
# Out:
# 4
# 5.7
# 6
# <class 'str'>
