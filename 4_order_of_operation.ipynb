# %% [markdown]
# ##### Please Excuse My Dear Aunt Sally
#  - Parenthesis
#  - Exponents
#  - Multiplication
#  - Division
#  - Addition
#  - Subraction

# %% [markdown]
# ##### For the below example, the spacing is not a concern
#  - first it starts with multiplication - 2 * 9 = 18
#  - then addition - 18 + 7 = 25
#  - then subraction - 25 - 8 = 17

# %%
7 + 2   *    9-8
# Out:
# 17

# %% [markdown]
# ##### Excercise
#  - Add required order of operations to make the ans mentioned below
#     - 4 x 5 / 7 + 3 = 2
#     - 9 / 3 + 6 - 1 = 0

# %%
(4*5)/(7+3)
# Out:
# 2.0

# %%
(9/(3+6))-1
# Out:
# 0.0
